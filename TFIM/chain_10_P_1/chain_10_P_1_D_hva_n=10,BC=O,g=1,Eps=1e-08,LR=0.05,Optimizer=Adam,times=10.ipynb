# %%
import matplotlib.pyplot as plt

D = [4,8,12,16,20,24]

# %%
avg_E = [-12.481433105468749,-12.783267974853516,-12.784740447998047,-12.784794139862061,-12.784881973266602,-12.784875965118408]
min_E = [-12.614265441894531,-12.784571647644043,-12.784906387329102,-12.784905433654785,-12.784901618957520,-12.784906387329102]
baseline_E = [-12.784906442999322,-12.784906442999322,-12.784906442999322,-12.784906442999322,-12.784906442999322,-12.784906442999322]

# This graph shows how Ground State Energy changes over Circuit Depth.

plt.plot(D, baseline_E, "r--",label="baseline")
plt.plot(D, avg_E, "b.-",label="avg E")
plt.plot(D, min_E, "g.-",label="min E")
plt.xlabel('Circuit Depth')
plt.ylabel('Ground State Energy')
plt.title('Energy Approximation')
plt.xticks(range(4,28,4))
plt.legend()
plt.show()

# %%
plt.cla()

# This graph shows how Iterations changes over Circuit Depth.

avg_ITR = [1058,411,191,117,124,131]

plt.plot(D, avg_ITR, "r.-")
plt.xlabel('Circuit Depth')
plt.ylabel('Number of Iterations')
plt.title('Average Iterations')
plt.xticks(range(4,28,4))
plt.show()

# %%
plt.cla()

avg_varE = [0.348081724058283748,0.009238087510675541,0.000972536901645071,0.000625708560164639,0.000189326318104577,0.000178625933131116]
varE_of_min_E = [0.303784534276928753,0.002100222779517935,0.000095981205959106,0.000004698012162407,0.000086980296146066,0.000019687260646606]

# This graph shows how Energy Variance(VarE) changes over Circuit Depth.

plt.plot(D, avg_varE, "r.-",label="Avg VarE")
plt.plot(D, varE_of_min_E, "g.-",label="VarE of Min E")
plt.xlabel('Circuit Depth')
plt.ylabel('Energy Variance, VarE')
plt.title('Energy Variance, VarE')
plt.xticks(range(4,28,4))
plt.legend()
plt.show()

# %%
plt.cla()

avg_v_score = [0.022916184066930335,0.000565377071087526,0.000059501884769223,0.000038281466447922,0.000011582927477292,0.000010928436998973]
v_score_of_min_E = [0.019091573722867017,0.000128497003986227,0.000005872068288427,0.000000287421397528,0.000005321402399611,0.000001204453911302]

# This graph shows how V_Score changes over Circuit Depth.

plt.plot(D, avg_v_score, "r.-",label="Avg V_Score")
plt.plot(D, v_score_of_min_E, "g.-",label="V_Score of Min E")
plt.xlabel('Circuit Depth')
plt.ylabel('V_Score')
plt.title('V_Score')
plt.xticks(range(4,28,4))
plt.legend()
plt.show()
