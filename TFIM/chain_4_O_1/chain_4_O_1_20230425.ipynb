# %%
import matplotlib.pyplot as plt

D = [4,6,8,10]

# %%
# All Min E
mbhva_E = [-4.758764266967773,-7.295692920684814,-9.794462203979492,-12.344557762145996]
hva_E = [-4.758766651153564,-7.296122074127197,-9.835680007934570,-12.350627899169922]
baseline_E = [-4.7587704831436330,-7.2962298105587560,-9.8379514474594170,-12.381489999654720]

# This graph shows how Ground State Energy changes over Circuit Depth.

plt.plot(D, baseline_E, "r--",label="baseline")
plt.plot(D, mbhva_E, "b.-",label="mbhva_E E")
plt.plot(D, hva_E, "g.-",label="hva E")
plt.xlabel('Circuit Depth')
plt.ylabel('Ground State Energy')
plt.title('Energy Approximation')
plt.xticks(range(4,12,2))
plt.legend()
plt.show()

# %%
plt.cla()

mbhva_v_score = [0.000006141087918628,0.000289341469510308,0.008947883683645855,0.005622424183081313]
hva_v_score = [0.000003143709874297,0.000057310451231710,0.003242245636550293,0.004487476122004844]

# This graph shows how V_Score changes over Circuit Depth.

plt.plot(D, mbhva_v_score, "r.-",label="mbhva v_score")
plt.plot(D, hva_v_score, "g.-",label="hva v_score")
plt.xlabel('Circuit Depth')
plt.ylabel('V_Score')
plt.title('V_Score')
plt.xticks(range(4,12,2))
plt.legend()
plt.show()
