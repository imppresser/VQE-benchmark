# %%
import matplotlib.pyplot as plt

D = [4,8,12,16,20,24]

# %%
avg_E = [-12.100448799133300,-12.379119682312012,-12.380456161499023,-12.380671787261964,-12.380875492095948,-12.381036090850831]
min_E = [-12.356305122375488,-12.380517959594727,-12.381144523620605,-12.381236076354980,-12.381299972534180,-12.381318092346191]
baseline_E = [-12.381489999654734,-12.381489999654734,-12.381489999654734,-12.381489999654734,-12.381489999654734,-12.381489999654734]

# This graph shows how Ground State Energy changes over Circuit Depth.

plt.plot(D, baseline_E, "r--",label="baseline")
plt.plot(D, avg_E, "b.-",label="avg E")
plt.plot(D, min_E, "g.-",label="min E")
plt.xlabel('Circuit Depth')
plt.ylabel('Ground State Energy')
plt.title('Energy Approximation')
plt.xticks(range(4,28,4))
plt.legend()
plt.show()

# %%
plt.cla()

# This graph shows how Iterations changes over Circuit Depth.

avg_ITR = [935,412,263,179,168,201]

plt.plot(D, avg_ITR, "r.-")
plt.xlabel('Circuit Depth')
plt.ylabel('Number of Iterations')
plt.title('Average Iterations')
plt.xticks(range(4,28,4))
plt.show()

# %%
plt.cla()

avg_varE = [0.107899172877478119,0.008065047089257860,0.004322156705711677,0.003461367050931585,0.002978370763685234,0.002192250764983328]
varE_of_min_E = [0.055518888772894570,0.003338406644616043,0.001632843813240470,0.001303646370615752,0.000926859265746316,0.000951187742430193]

# This graph shows how Energy Variance(VarE) changes over Circuit Depth.

plt.plot(D, avg_varE, "r.-",label="Avg VarE")
plt.plot(D, varE_of_min_E, "g.-",label="VarE of Min E")
plt.xlabel('Circuit Depth')
plt.ylabel('Energy Variance, VarE')
plt.title('Energy Variance, VarE')
plt.xticks(range(4,28,4))
plt.legend()
plt.show()

# %%
plt.cla()

avg_v_score = [0.007645902633703747,0.000526313555594591,0.000281991429471812,0.000225829070382069,0.000194305273164997,0.000143016592783636]
v_score_of_min_E = [0.003636331908285361,0.000217801871462113,0.000106518013591418,0.000085041672133521,0.000060461832303823,0.000062048670781735]

# This graph shows how V_Score changes over Circuit Depth.

plt.plot(D, avg_v_score, "r.-",label="Avg V_Score")
plt.plot(D, v_score_of_min_E, "g.-",label="V_Score of Min E")
plt.xlabel('Circuit Depth')
plt.ylabel('V_Score')
plt.title('V_Score')
plt.xticks(range(4,28,4))
plt.legend()
plt.show()
