# %%
import matplotlib.pyplot as plt

D = [4,6,8,10]

# %%
# All Min E
mbhva_E = [-6.464096069335938,-9.974113464355469,-13.494147300720215,-17.007127761840820]
hva_E = [-6.464095115661621,-9.974303245544434,-13.494368553161621,-16.968536376953125]
baseline_E = [-6.464101615137754,-9.9743085355517050,-13.499730394751571,-17.032140829131503]

# This graph shows how Ground State Energy changes over Circuit Depth.

plt.plot(D, baseline_E, "r--",label="baseline")
plt.plot(D, mbhva_E, "b.-",label="mbhva_E E")
plt.plot(D, hva_E, "g.-",label="hva E")
plt.xlabel('Circuit Depth')
plt.ylabel('Ground State Energy')
plt.title('Energy Approximation')
plt.xticks(range(4,12,2))
plt.legend()
plt.show()

# %%
plt.cla()

mbhva_v_score = [0.000003312968452337,0.000102228558217371,0.002955654121509909,0.007168480314270594]
hva_v_score = [0.000005223598123612,0.000003197926095011,0.003242245636550293,0.003794476782004602]

# This graph shows how V_Score changes over Circuit Depth.

plt.plot(D, mbhva_v_score, "r.-",label="mbhva v_score")
plt.plot(D, hva_v_score, "g.-",label="hva v_score")
plt.xlabel('Circuit Depth')
plt.ylabel('V_Score')
plt.title('V_Score')
plt.xticks(range(4,12,4))
plt.legend()
plt.show()
